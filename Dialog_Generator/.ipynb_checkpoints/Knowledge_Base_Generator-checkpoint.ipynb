# %% [markdown]
# # Welcome to Game of Dialogs

# %% [markdown]
# ## Description
#
# Game of Dialogs is an attempt to create a Knowledge Base for creating conversational datasets for building end to end dialog systems
#
# ### What is the Knowledge Base ?
#
# A Knowledge Base is a publically available Data Base that can be used to generate profiles that will be used to make unique and disctict conversations

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import random

# %% [markdown]
# ## Game of Dialogs.xlsx
#
# Below is the file called Game of Dialogs.xlsx. The filed contains the suggested values for each of the slot that we intend to use to create the dialog.
# From this excel sheet, then we create a list of possible values which will then be used to create the various user profiles for the Dialog.

# %%
data_frame = pd.read_excel('Game_of_Dialogs.xlsx','VARIABLE_VALUES')

# %% [markdown]
# In this cell we create the user_values for the various user profiles

# %%
user_values = dict()
for index,row in data_frame.iterrows() :
    for column in data_frame.columns :
        list_of_values = list()
        if column in user_values.keys() :
            list_of_values = user_values[column]
        if not pd.isnull(row[column]) :
            list_of_values.append(row[column])
        user_values[column] = list_of_values

# %%
data_frame_value_association = pd.read_excel('Game_of_Dialogs.xlsx','COMPANY_ROLE')
partner_role_dict = dict()

for index,row in data_frame_value_association.iterrows() :
    if row["note"] in partner_role_dict.keys() :
        list_of_organizations = partner_role_dict[row["note"]]
    else :
        list_of_organizations = list()
        
    if not pd.isnull(row["company_name"]) :
        list_of_organizations.append(row["company_name"])
        partner_role_dict[row["note"]] = list_of_organizations

print(partner_role_dict)
# Out:
# {'salary': ['STARK INDUSTRIES', 'PYM INDUSTRIES', 'ACME CORP'], 'electricity bill': ['BURNS INDUSTRIES', 'POWER CORP', 'ENERGY DISTRIBUTORS'], 'telephone bill': ['SUPER NETWORK', 'CONNECTION GENE', 'INTERCONNECT TECH'], 'pension': ['STARK INDUSTRIES', 'PYM INDUSTRIES', 'ENERGY DISTRIBUTORS']}

# %%
data_frame_note_flow = pd.read_excel('Game_of_Dialogs.xlsx','FLOW_DICTIONARY')
note_flow_dict = dict()

for index,row in data_frame_note_flow.iterrows() :
    if row["accounted/credited"] in note_flow_dict.keys() :
        list_of_notes = note_flow_dict[row["accounted/credited"]]
    else :
        list_of_notes = list()
        
    if not pd.isnull(row["note"]) :
        list_of_notes.append(row["note"])
        note_flow_dict[row["accounted/credited"]] = list_of_notes
print(note_flow_dict)
# Out:
# {'credited': ['salary', 'pension', 'money transfer'], 'accounted': ['electricity bill', 'telephone bill', 'money transfer', 'house rent']}

# %% [markdown]
# ## How to create User values
#
# Below you will see the creation of two items i.e **list_of_columns** and **knowledge_base**
#
# 1. **list_of_collumns** : Contains the user slot values that we intend for each _user profile_
# 2. **knowledge_base** : This is the data_frame that is usually converted to an excel file that displays various user_profiles

# %%
list_of_columns = ['name','partner_names','user_accounts','balance','limit','transaction_ids','card_names','card_ids','notes','note:associated_partner','note:flow','note:amount','note:date','company_names']
knowledge_base = pd.DataFrame(columns=list_of_columns)

# %% [markdown]
# Function to create the knowledge base and convert it to an excel sheet

# %%
def create_user_profiles(number_of_profiles,user_values,file_name,list_of_columns,knowledge_base) :
    
    profile_set = list()
    count = 1
    while len(profile_set) < number_of_profiles :
        custom_user = dict()
        
        #1 Set up name
        custom_user['name'] = "player_{}".format(str(count))
        count += 1
        
        #2 Set up partner names
        number_of_partners = random.randint(1,len(user_values['partner_names']))
        custom_user_partner_names = random.sample(user_values['partner_names'],number_of_partners)
        custom_user['partner_names'] = ','.join(custom_user_partner_names)
        
        #3 Set user_accounts
        number_of_accounts = random.randint(1,len(user_values['user_accounts']))
        custom_user_accounts = random.sample(user_values['user_accounts'],number_of_accounts)
        custom_user['user_accounts'] = ','.join(custom_user_accounts)
        
        #4 Set balance
        custom_user['balance'] = random.sample(user_values['amount_values'],1)[0]
        
        #5 Set limit
        custom_user['limit'] = random.sample(user_values['amount_values'],1)[0]
        
        #6 Set transaction_ids
        number_of_partner_for_transaction_ids = random.randint(1,len(custom_user_partner_names))
        list_of_partners_with_transaction_ids = random.sample(custom_user_partner_names,number_of_partner_for_transaction_ids)
        
        transaction_id_list = list()
        
        for partner in list_of_partners_with_transaction_ids :
            
            account_chosen = random.sample(custom_user_accounts,1)[0]
            amount_chosen = random.sample(user_values['amount_values'],1)[0]
            
            while amount_chosen > custom_user["limit"] :
                amount_chosen = random.sample(user_values["amount_values"],1)[0]
            
            transaction_id_created = "{}-{}-{}".format(partner,int(amount_chosen),account_chosen)
            
            transaction_id_list.append(transaction_id_created)
            
        custom_user['transaction_ids'] = ','.join(transaction_id_list)
        
        #7 Set card names
        number_of_cards = random.randint(1,len(user_values['card_names']))
        custom_user_card_names = random.sample(user_values['card_names'],number_of_cards)
        custom_user['card_names'] = ','.join(custom_user_card_names)
        
        
        #8 Set card_ids
        card_id_list = list()
        for card_name in custom_user_card_names :
            linked_account = random.sample(custom_user_accounts,1)[0]
            card_id = '{}-{}'.format(card_name,linked_account)
            card_id_list.append(card_id)
            
        custom_user['card_ids'] = ','.join(card_id_list)
        
        
        #9 Set notes
        number_of_notes = random.randint(1,len(user_values['notes']))
        custom_user_notes = random.sample(user_values['notes'],number_of_notes)
        custom_user['notes'] = ','.join(custom_user_notes)
        
        
        #10 Set note:associated_partner
        list_of_companies = list()
        note_associated_partner_list = list()
        for note in custom_user_notes :
            list_of_associated_partners = partner_role_dict[note]
            associated_partner = random.sample(list_of_associated_partners,1)[0]
            if associated_partner not in list_of_companies :
                list_of_companies.append(associated_partner)
                
            note_associated_partner = "{}:{}".format(note,associated_partner)
            note_associated_partner_list.append(note_associated_partner)
        custom_user["note:associated_partner"] = ','.join(note_associated_partner_list)
        
        #11 Set note:flow
        note_flow_list = list()
        for flow in note_flow_dict.keys() :
            for note in custom_user_notes :
                if note in note_flow_dict[flow] :
                    note_flow_list.append("{}:{}".format(note,flow))
        custom_user["note:flow"] = ','.join(note_flow_list)
        
        #12 Set note:amount
        note_associated_amount_list = list()
        for note in customer_user_notes :
            amount_chosen = random.sample(user_values["amount_values"])
            
            while amount_chosen > custom_user["limit"] :
                amount_chosen = random.sample(user_values["amount_values"])
            note_associated_amount = "{}:{}".format(note,amount)
            note_associated_amount_list.append(note_associated_amount)
            
        custom_user["note:amount"] = ','.join(note_associated_amount_list)
        
        #13 Set note:date
        note_associated_date_list = list()
        for note in custom_user_notes :
            fake_date = fake.date_between(start_date='-20y',end_date='+1y')
            date = '{}-{}-{}'.format(fake_date.day,fake_day.month,fake_date.year)
            note_associated_date = '{}:{}'.format(note,date)
            note_associated_list.append(note_associated_date)
        
        custom_user["note:date"] = ','.join(note_associated_date_list)
        
        #14 Set company names
        custom_user["company_names"] = ','.join(list_of_companies)
        
        if custom_user not in profile_set :
            profile_set.append(custom_user)
        
    for user_profile in profile_set :
        knowledge_base = knowledge_base.append(user_profile,ignore_index=True)
        
    excel_writer = pd.ExcelWriter(file_name)
    knowledge_base.to_excel(excel_writer,sheet_name='UserValues')
    excel_writer.save()
    return knowledge_base

# %%
knowledge_base = create_user_profiles(number_of_profiles=100,user_values=user_values,file_name='user_values.xlsx',list_of_columns=list_of_columns,knowledge_base=knowledge_base)

# %%
print(knowledge_base)
# Out:
#           name                                      partner_names  \
# 0     player_1  megan,harry,emma,james,lily,sarah,michael,thom...
# 1     player_2                                        james,harry
# 2     player_3                                         lily,megan
# 3     player_4                             emma,sarah,olivia,lily
# 4     player_5  olivia,michael,thomas,harry,emma,sarah,megan,j...
# 5     player_6          megan,thomas,lily,james,michael,emma,jack
# 6     player_7          lily,megan,harry,thomas,olivia,sarah,jack
# 7     player_8               james,harry,megan,jack,olivia,thomas
# 8     player_9                                         lily,james
# 9    player_10                                     jack,emma,lily
# 10   player_11                      lily,michael,harry,emma,sarah
# 11   player_12                                              harry
# 12   player_13  emma,thomas,olivia,harry,james,jack,michael,sarah
# 13   player_14                      megan,lily,harry,james,thomas
# 14   player_15                                            michael
# 15   player_16                             thomas,emma,sarah,jack
# 16   player_17                                  sarah,megan,harry
# 17   player_18        harry,michael,sarah,lily,james,olivia,megan
# 18   player_19  olivia,harry,jack,sarah,james,emma,megan,thoma...
# 19   player_20               thomas,olivia,harry,jack,james,sarah
# 20   player_21  jack,sarah,harry,olivia,emma,james,megan,micha...
# 21   player_22              emma,sarah,james,michael,megan,thomas
# 22   player_23  emma,michael,jack,harry,thomas,olivia,james,sa...
# 23   player_24             sarah,thomas,michael,olivia,lily,james
# 24   player_25  olivia,sarah,lily,michael,harry,james,thomas,jack
# 25   player_26                          harry,thomas,lily,michael
# 26   player_27                           michael,sarah,jack,james
# 27   player_28                                        sarah,megan
# 28   player_29  megan,lily,jack,olivia,michael,sarah,thomas,ja...
# 29   player_30  lily,olivia,jack,megan,james,sarah,thomas,emma...
# ..         ...                                                ...
# 70   player_71               jack,sarah,emma,harry,michael,olivia
# 71   player_72           emma,megan,lily,sarah,michael,jack,harry
# 72   player_73                                 olivia,megan,sarah
# 73   player_74                                  lily,sarah,olivia
# 74   player_75                     michael,megan,emma,olivia,lily
# 75   player_76                                    sarah,lily,emma
# 76   player_77                                             olivia
# 77   player_78                             megan,emma,olivia,lily
# 78   player_79          olivia,thomas,harry,jack,megan,emma,james
# 79   player_80  lily,olivia,jack,megan,thomas,harry,michael,ja...
# 80   player_81          lily,jack,thomas,emma,harry,megan,michael
# 81   player_82               michael,lily,harry,thomas,emma,james
# 82   player_83                       lily,james,olivia,sarah,emma
# 83   player_84                                            michael
# 84   player_85                       megan,james,jack,lily,olivia
# 85   player_86                     james,megan,olivia,emma,thomas
# 86   player_87           megan,thomas,james,olivia,emma,jack,lily
# 87   player_88                       sarah,olivia,jack,james,lily
# 88   player_89                                      sarah,michael
# 89   player_90                 emma,james,sarah,megan,jack,olivia
# 90   player_91                                             thomas
# 91   player_92                     sarah,thomas,olivia,jack,harry
# 92   player_93                                              james
# 93   player_94                                             thomas
# 94   player_95                                      thomas,olivia
# 95   player_96                     thomas,lily,megan,michael,jack
# 96   player_97                                         james,jack
# 97   player_98    lily,jack,emma,sarah,thomas,james,harry,michael
# 98   player_99  sarah,megan,james,jack,olivia,lily,thomas,emma...
# 99  player_100                                       thomas,james
#
#                                   user_accounts  balance   limit  \
# 0                                         joint    100.0   500.0
# 1                                  credit,joint   1000.0   100.0
# 2                          savings,credit,joint    500.0   500.0
# 3                           joint,fixed deposit   1000.0   100.0
# 4                         checking,credit,joint   1000.0   500.0
# 5                  savings,credit,fixed deposit    100.0   500.0
# 6                 credit,joint,checking,savings   1000.0   100.0
# 7                                        credit   1000.0   100.0
# 8                 checking,credit,fixed deposit   1000.0  1000.0
# 9            joint,savings,credit,fixed deposit    100.0  1000.0
# 10         savings,fixed deposit,checking,joint    100.0   100.0
# 11          fixed deposit,joint,checking,credit    500.0   500.0
# 12  joint,checking,credit,savings,fixed deposit    100.0  1000.0
# 13                               savings,credit    100.0   100.0
# 14  fixed deposit,savings,joint,checking,credit    500.0  1000.0
# 15                                        joint    500.0  1000.0
# 16         fixed deposit,checking,joint,savings    500.0   500.0
# 17  credit,joint,fixed deposit,savings,checking    500.0   100.0
# 18  fixed deposit,joint,checking,savings,credit    500.0  1000.0
# 19                                        joint    500.0  1000.0
# 20                  joint,fixed deposit,savings   1000.0   100.0
# 21  checking,fixed deposit,credit,savings,joint    100.0  1000.0
# 22                                savings,joint   1000.0  1000.0
# 23                                joint,savings    500.0  1000.0
# 24  savings,fixed deposit,joint,checking,credit   1000.0   500.0
# 25                joint,checking,savings,credit    500.0   500.0
# 26        credit,checking,fixed deposit,savings    100.0   100.0
# 27  fixed deposit,joint,credit,checking,savings    100.0   500.0
# 28                                        joint    100.0   100.0
# 29                         joint,savings,credit   1000.0   500.0
# ..                                          ...      ...     ...
# 70                  fixed deposit,joint,savings   1000.0   100.0
# 71                               joint,checking    100.0   500.0
# 72  fixed deposit,savings,credit,joint,checking    500.0   100.0
# 73                 savings,credit,fixed deposit    100.0   500.0
# 74                              checking,credit    500.0   500.0
# 75  checking,joint,savings,credit,fixed deposit    100.0   500.0
# 76                              checking,credit    100.0   100.0
# 77               checking,savings,fixed deposit    100.0  1000.0
# 78  checking,credit,fixed deposit,savings,joint   1000.0   100.0
# 79                                     checking   1000.0   100.0
# 80                                savings,joint   1000.0  1000.0
# 81                                     checking   1000.0  1000.0
# 82                                     checking   1000.0   500.0
# 83                             savings,checking    500.0  1000.0
# 84        checking,savings,credit,fixed deposit   1000.0   500.0
# 85                 fixed deposit,credit,savings    500.0   500.0
# 86                                     checking    100.0   500.0
# 87  fixed deposit,checking,savings,joint,credit   1000.0  1000.0
# 88                               savings,credit    100.0   500.0
# 89         fixed deposit,savings,joint,checking   1000.0   500.0
# 90        savings,fixed deposit,credit,checking    500.0  1000.0
# 91           fixed deposit,credit,savings,joint    500.0   500.0
# 92                checking,joint,savings,credit   1000.0   500.0
# 93                                fixed deposit   1000.0  1000.0
# 94                             savings,checking   1000.0   100.0
# 95                                        joint    100.0   500.0
# 96                        fixed deposit,savings    500.0   100.0
# 97                       joint,savings,checking    500.0  1000.0
# 98  savings,fixed deposit,joint,credit,checking    100.0  1000.0
# 99                                      savings   1000.0   100.0
#
#                                       transaction_ids  \
# 0    james-500-joint,olivia-100-joint,sarah-100-joint
# 1                     harry-100-joint,james-100-joint
# 2                   lily-500-savings,megan-100-credit
# 3   emma-100-joint,olivia-100-joint,sarah-100-fixe...
# 4   harry-500-credit,emma-500-joint,sarah-100-chec...
# 5   emma-500-savings,megan-500-savings,michael-100...
# 6   thomas-100-savings,jack-100-credit,lily-100-cr...
# 7   harry-100-credit,megan-100-credit,jack-100-cre...
# 8                                    james-500-credit
# 9              jack-100-fixed deposit,lily-1000-joint
# 10  lily-100-fixed deposit,sarah-100-checking,harr...
# 11                                    harry-500-joint
# 12                                 olivia-100-savings
# 13  thomas-100-credit,james-100-credit,harry-100-c...
# 14                                michael-500-savings
# 15                                    emma-1000-joint
# 16  megan-100-savings,sarah-500-savings,harry-500-...
# 17  lily-100-checking,megan-100-savings,olivia-100...
# 18  james-100-savings,jack-500-fixed deposit,sarah...
# 19                                  olivia-1000-joint
# 20                                    harry-100-joint
# 21  thomas-100-joint,emma-500-fixed deposit,megan-...
# 22  sarah-100-savings,harry-1000-savings,lily-100-...
# 23  olivia-500-savings,james-500-savings,thomas-10...
# 24  michael-500-credit,harry-100-fixed deposit,tho...
# 25  thomas-100-credit,lily-500-joint,harry-100-joi...
# 26  jack-100-savings,james-100-credit,michael-100-...
# 27                  megan-500-credit,sarah-100-credit
# 28                                    harry-100-joint
# 29                      emma-500-joint,jack-500-joint
# ..                                                ...
# 70   emma-100-joint,jack-100-joint,olivia-100-savings
# 71                                 megan-500-checking
# 72                megan-100-savings,olivia-100-credit
# 73  lily-500-savings,olivia-100-savings,sarah-100-...
# 74  emma-100-checking,lily-100-credit,michael-500-...
# 75            sarah-500-credit,lily-100-fixed deposit
# 76                                olivia-100-checking
# 77  olivia-500-fixed deposit,megan-100-fixed depos...
# 78                                    megan-100-joint
# 79               jack-100-checking,harry-100-checking
# 80  thomas-500-joint,emma-500-savings,jack-1000-sa...
# 81  harry-100-checking,lily-1000-checking,thomas-1...
# 82  sarah-500-checking,james-500-checking,lily-500...
# 83                               michael-1000-savings
# 84  megan-100-savings,jack-500-fixed deposit,lily-...
# 85  olivia-500-credit,thomas-500-credit,emma-100-f...
# 86  megan-500-checking,james-100-checking,thomas-5...
# 87                           olivia-100-fixed deposit
# 88              michael-100-savings,sarah-500-savings
# 89  james-100-checking,olivia-100-checking,megan-5...
# 90                                  thomas-100-credit
# 91  thomas-500-fixed deposit,olivia-100-fixed depo...
# 92                                 james-100-checking
# 93                           thomas-100-fixed deposit
# 94             olivia-100-checking,thomas-100-savings
# 95  lily-100-joint,thomas-100-joint,megan-100-join...
# 96           james-100-fixed deposit,jack-100-savings
# 97  thomas-1000-joint,jack-500-checking,michael-50...
# 98                                  emma-1000-savings
# 99                                  james-100-savings
#
#                                            card_names  \
# 0                                          fleet card
# 1                                         credit card
# 2   credit card,prepaid card,stored value card,fle...
# 3   debit card,prepaid card,stored value card,cred...
# 4   fleet card,credit card,debit card,stored value...
# 5   fleet card,stored value card,debit card,credit...
# 6                                   stored value card
# 7   stored value card,credit card,fleet card,debit...
# 8      debit card,credit card,fleet card,prepaid card
# 9                               fleet card,debit card
# 10  prepaid card,credit card,debit card,stored val...
# 11                                  stored value card
# 12  fleet card,stored value card,debit card,credit...
# 13  stored value card,fleet card,prepaid card,debi...
# 14                             credit card,debit card
# 15  fleet card,debit card,prepaid card,stored valu...
# 16  stored value card,credit card,debit card,prepa...
# 17                fleet card,prepaid card,credit card
# 18                                  stored value card
# 19  stored value card,credit card,fleet card,prepa...
# 20  fleet card,stored value card,debit card,prepai...
# 21  fleet card,stored value card,credit card,prepa...
# 22  stored value card,debit card,fleet card,prepai...
# 23            fleet card,debit card,stored value card
# 24  debit card,credit card,fleet card,prepaid card...
# 25                                  stored value card
# 26  stored value card,prepaid card,credit card,deb...
# 27     prepaid card,debit card,fleet card,credit card
# 28  prepaid card,credit card,debit card,stored val...
# 29  debit card,stored value card,prepaid card,flee...
# ..                                                ...
# 70     debit card,fleet card,credit card,prepaid card
# 71  stored value card,debit card,fleet card,prepai...
# 72                                         fleet card
# 73                fleet card,prepaid card,credit card
# 74  prepaid card,fleet card,stored value card,cred...
# 75                      stored value card,credit card
# 76                     stored value card,prepaid card
# 77                                       prepaid card
# 78  prepaid card,credit card,stored value card,fle...
# 79                            prepaid card,fleet card
# 80  prepaid card,fleet card,debit card,stored valu...
# 81                             credit card,fleet card
# 82  prepaid card,fleet card,credit card,stored val...
# 83  debit card,stored value card,fleet card,credit...
# 84     credit card,debit card,prepaid card,fleet card
# 85                       stored value card,fleet card
# 86  prepaid card,debit card,stored value card,cred...
# 87                            fleet card,prepaid card
# 88  credit card,prepaid card,fleet card,debit card...
# 89  stored value card,prepaid card,fleet card,debi...
# 90  fleet card,stored value card,debit card,prepai...
# 91                                       prepaid card
# 92                  credit card,debit card,fleet card
# 93                                         debit card
# 94                                        credit card
# 95  stored value card,fleet card,debit card,credit...
# 96  debit card,stored value card,credit card,fleet...
# 97  fleet card,stored value card,debit card,credit...
# 98                       fleet card,stored value card
# 99                                       prepaid card
#
#                                              card_ids  \
# 0                                    fleet card-joint
# 1                                   credit card-joint
# 2   credit card-credit,prepaid card-credit,stored ...
# 3   debit card-joint,prepaid card-joint,stored val...
# 4   fleet card-credit,credit card-checking,debit c...
# 5   fleet card-credit,stored value card-credit,deb...
# 6                          stored value card-checking
# 7   stored value card-credit,credit card-credit,fl...
# 8   debit card-credit,credit card-fixed deposit,fl...
# 9          fleet card-fixed deposit,debit card-credit
# 10  prepaid card-checking,credit card-checking,deb...
# 11                           stored value card-credit
# 12  fleet card-checking,stored value card-joint,de...
# 13  stored value card-credit,fleet card-savings,pr...
# 14         credit card-fixed deposit,debit card-joint
# 15  fleet card-joint,debit card-joint,prepaid card...
# 16  stored value card-joint,credit card-joint,debi...
# 17  fleet card-joint,prepaid card-fixed deposit,cr...
# 18                    stored value card-fixed deposit
# 19  stored value card-joint,credit card-joint,flee...
# 20  fleet card-joint,stored value card-fixed depos...
# 21  fleet card-credit,stored value card-checking,c...
# 22  stored value card-savings,debit card-savings,f...
# 23  fleet card-joint,debit card-joint,stored value...
# 24  debit card-checking,credit card-credit,fleet c...
# 25                          stored value card-savings
# 26  stored value card-savings,prepaid card-credit,...
# 27  prepaid card-joint,debit card-credit,fleet car...
# 28  prepaid card-joint,credit card-joint,debit car...
# 29  debit card-credit,stored value card-savings,pr...
# ..                                                ...
# 70  debit card-savings,fleet card-savings,credit c...
# 71  stored value card-checking,debit card-checking...
# 72                                  fleet card-credit
# 73  fleet card-savings,prepaid card-savings,credit...
# 74  prepaid card-credit,fleet card-credit,stored v...
# 75  stored value card-checking,credit card-fixed d...
# 76       stored value card-credit,prepaid card-credit
# 77                              prepaid card-checking
# 78  prepaid card-fixed deposit,credit card-credit,...
# 79          prepaid card-checking,fleet card-checking
# 80  prepaid card-savings,fleet card-joint,debit ca...
# 81           credit card-checking,fleet card-checking
# 82  prepaid card-checking,fleet card-checking,cred...
# 83  debit card-savings,stored value card-savings,f...
# 84  credit card-credit,debit card-savings,prepaid ...
# 85  stored value card-fixed deposit,fleet card-fix...
# 86  prepaid card-checking,debit card-checking,stor...
# 87      fleet card-savings,prepaid card-fixed deposit
# 88  credit card-credit,prepaid card-credit,fleet c...
# 89  stored value card-checking,prepaid card-joint,...
# 90  fleet card-savings,stored value card-checking,...
# 91                               prepaid card-savings
# 92  credit card-checking,debit card-joint,fleet ca...
# 93                           debit card-fixed deposit
# 94                                credit card-savings
# 95  stored value card-joint,fleet card-joint,debit...
# 96  debit card-savings,stored value card-fixed dep...
# 97  fleet card-savings,stored value card-checking,...
# 98      fleet card-savings,stored value card-checking
# 99                               prepaid card-savings
#
#                                              notes  \
# 0                    salary,telephone bill,pension
# 1                                           salary
# 2   salary,telephone bill,pension,electricity bill
# 3   electricity bill,pension,salary,telephone bill
# 4                                   pension,salary
# 5   electricity bill,pension,telephone bill,salary
# 6                                   pension,salary
# 7           electricity bill,telephone bill,salary
# 8   pension,telephone bill,electricity bill,salary
# 9   salary,telephone bill,electricity bill,pension
# 10                   pension,salary,telephone bill
# 11                                  telephone bill
# 12  electricity bill,pension,telephone bill,salary
# 13         pension,electricity bill,telephone bill
# 14                 telephone bill,electricity bill
# 15                                electricity bill
# 16                                  telephone bill
# 17         electricity bill,pension,telephone bill
# 18  pension,salary,electricity bill,telephone bill
# 19  telephone bill,salary,electricity bill,pension
# 20         pension,electricity bill,telephone bill
# 21                           telephone bill,salary
# 22                                          salary
# 23  pension,electricity bill,telephone bill,salary
# 24  electricity bill,salary,pension,telephone bill
# 25                                  salary,pension
# 26                 electricity bill,telephone bill
# 27                        electricity bill,pension
# 28                           telephone bill,salary
# 29          telephone bill,salary,electricity bill
# ..                                             ...
# 70                           salary,telephone bill
# 71  salary,telephone bill,electricity bill,pension
# 72          salary,telephone bill,electricity bill
# 73                   pension,telephone bill,salary
# 74                 telephone bill,electricity bill
# 75                                          salary
# 76          telephone bill,electricity bill,salary
# 77         telephone bill,pension,electricity bill
# 78  telephone bill,electricity bill,salary,pension
# 79                   telephone bill,salary,pension
# 80                        electricity bill,pension
# 81                                  telephone bill
# 82                           salary,telephone bill
# 83                         salary,electricity bill
# 84                        pension,electricity bill
# 85                                  salary,pension
# 86                        electricity bill,pension
# 87                         salary,electricity bill
# 88  pension,telephone bill,electricity bill,salary
# 89                 pension,salary,electricity bill
# 90                                  salary,pension
# 91                                  salary,pension
# 92  salary,telephone bill,electricity bill,pension
# 93                                          salary
# 94                                  pension,salary
# 95                                electricity bill
# 96          salary,telephone bill,electricity bill
# 97          electricity bill,telephone bill,salary
# 98  salary,pension,telephone bill,electricity bill
# 99                          pension,telephone bill
#
#                               note:associated_partner  \
# 0   salary:STARK INDUSTRIES,telephone bill:INTERCO...
# 1                               salary:PYM INDUSTRIES
# 2   salary:STARK INDUSTRIES,telephone bill:CONNECT...
# 3   electricity bill:BURNS INDUSTRIES,pension:PYM ...
# 4    pension:STARK INDUSTRIES,salary:STARK INDUSTRIES
# 5   electricity bill:POWER CORP,pension:PYM INDUST...
# 6      pension:PYM INDUSTRIES,salary:STARK INDUSTRIES
# 7   electricity bill:ENERGY DISTRIBUTORS,telephone...
# 8   pension:STARK INDUSTRIES,telephone bill:INTERC...
# 9   salary:ACME CORP,telephone bill:SUPER NETWORK,...
# 10  pension:PYM INDUSTRIES,salary:PYM INDUSTRIES,t...
# 11                     telephone bill:CONNECTION GENE
# 12  electricity bill:POWER CORP,pension:ENERGY DIS...
# 13  pension:ENERGY DISTRIBUTORS,electricity bill:E...
# 14  telephone bill:CONNECTION GENE,electricity bil...
# 15                  electricity bill:BURNS INDUSTRIES
# 16                   telephone bill:INTERCONNECT TECH
# 17  electricity bill:POWER CORP,pension:ENERGY DIS...
# 18  pension:ENERGY DISTRIBUTORS,salary:ACME CORP,e...
# 19  telephone bill:CONNECTION GENE,salary:STARK IN...
# 20  pension:ENERGY DISTRIBUTORS,electricity bill:B...
# 21      telephone bill:SUPER NETWORK,salary:ACME CORP
# 22                                   salary:ACME CORP
# 23  pension:STARK INDUSTRIES,electricity bill:BURN...
# 24  electricity bill:BURNS INDUSTRIES,salary:STARK...
# 25          salary:ACME CORP,pension:STARK INDUSTRIES
# 26  electricity bill:ENERGY DISTRIBUTORS,telephone...
# 27  electricity bill:POWER CORP,pension:ENERGY DIS...
# 28  telephone bill:CONNECTION GENE,salary:PYM INDU...
# 29  telephone bill:SUPER NETWORK,salary:PYM INDUST...
# ..                                                ...
# 70  salary:STARK INDUSTRIES,telephone bill:SUPER N...
# 71  salary:STARK INDUSTRIES,telephone bill:INTERCO...
# 72  salary:ACME CORP,telephone bill:SUPER NETWORK,...
# 73  pension:PYM INDUSTRIES,telephone bill:SUPER NE...
# 74  telephone bill:INTERCONNECT TECH,electricity b...
# 75                            salary:STARK INDUSTRIES
# 76  telephone bill:INTERCONNECT TECH,electricity b...
# 77  telephone bill:SUPER NETWORK,pension:PYM INDUS...
# 78  telephone bill:CONNECTION GENE,electricity bil...
# 79  telephone bill:SUPER NETWORK,salary:ACME CORP,...
# 80  electricity bill:BURNS INDUSTRIES,pension:STAR...
# 81                       telephone bill:SUPER NETWORK
# 82  salary:PYM INDUSTRIES,telephone bill:INTERCONN...
# 83  salary:PYM INDUSTRIES,electricity bill:BURNS I...
# 84  pension:PYM INDUSTRIES,electricity bill:BURNS ...
# 85          salary:ACME CORP,pension:STARK INDUSTRIES
# 86  electricity bill:BURNS INDUSTRIES,pension:ENER...
# 87  salary:PYM INDUSTRIES,electricity bill:POWER CORP
# 88  pension:ENERGY DISTRIBUTORS,telephone bill:INT...
# 89  pension:PYM INDUSTRIES,salary:ACME CORP,electr...
# 90            salary:ACME CORP,pension:PYM INDUSTRIES
# 91   salary:STARK INDUSTRIES,pension:STARK INDUSTRIES
# 92  salary:STARK INDUSTRIES,telephone bill:INTERCO...
# 93                                   salary:ACME CORP
# 94     pension:PYM INDUSTRIES,salary:STARK INDUSTRIES
# 95                  electricity bill:BURNS INDUSTRIES
# 96  salary:ACME CORP,telephone bill:INTERCONNECT T...
# 97  electricity bill:BURNS INDUSTRIES,telephone bi...
# 98  salary:PYM INDUSTRIES,pension:STARK INDUSTRIES...
# 99  pension:STARK INDUSTRIES,telephone bill:CONNEC...
#
#                                             note:flow  \
# 0   salary:credited,pension:credited,telephone bil...
# 1                                     salary:credited
# 2   salary:credited,pension:credited,telephone bil...
# 3   pension:credited,salary:credited,electricity b...
# 4                    pension:credited,salary:credited
# 5   pension:credited,salary:credited,electricity b...
# 6                    pension:credited,salary:credited
# 7   salary:credited,electricity bill:accounted,tel...
# 8   pension:credited,salary:credited,telephone bil...
# 9   salary:credited,pension:credited,telephone bil...
# 10  pension:credited,salary:credited,telephone bil...
# 11                           telephone bill:accounted
# 12  pension:credited,salary:credited,electricity b...
# 13  pension:credited,electricity bill:accounted,te...
# 14  telephone bill:accounted,electricity bill:acco...
# 15                         electricity bill:accounted
# 16                           telephone bill:accounted
# 17  pension:credited,electricity bill:accounted,te...
# 18  pension:credited,salary:credited,electricity b...
# 19  salary:credited,pension:credited,telephone bil...
# 20  pension:credited,electricity bill:accounted,te...
# 21           salary:credited,telephone bill:accounted
# 22                                    salary:credited
# 23  pension:credited,salary:credited,electricity b...
# 24  salary:credited,pension:credited,electricity b...
# 25                   salary:credited,pension:credited
# 26  electricity bill:accounted,telephone bill:acco...
# 27        pension:credited,electricity bill:accounted
# 28           salary:credited,telephone bill:accounted
# 29  salary:credited,telephone bill:accounted,elect...
# ..                                                ...
# 70           salary:credited,telephone bill:accounted
# 71  salary:credited,pension:credited,telephone bil...
# 72  salary:credited,telephone bill:accounted,elect...
# 73  pension:credited,salary:credited,telephone bil...
# 74  telephone bill:accounted,electricity bill:acco...
# 75                                    salary:credited
# 76  salary:credited,telephone bill:accounted,elect...
# 77  pension:credited,telephone bill:accounted,elec...
# 78  salary:credited,pension:credited,telephone bil...
# 79  salary:credited,pension:credited,telephone bil...
# 80        pension:credited,electricity bill:accounted
# 81                           telephone bill:accounted
# 82           salary:credited,telephone bill:accounted
# 83         salary:credited,electricity bill:accounted
# 84        pension:credited,electricity bill:accounted
# 85                   salary:credited,pension:credited
# 86        pension:credited,electricity bill:accounted
# 87         salary:credited,electricity bill:accounted
# 88  pension:credited,salary:credited,telephone bil...
# 89  pension:credited,salary:credited,electricity b...
# 90                   salary:credited,pension:credited
# 91                   salary:credited,pension:credited
# 92  salary:credited,pension:credited,telephone bil...
# 93                                    salary:credited
# 94                   pension:credited,salary:credited
# 95                         electricity bill:accounted
# 96  salary:credited,telephone bill:accounted,elect...
# 97  salary:credited,electricity bill:accounted,tel...
# 98  salary:credited,pension:credited,telephone bil...
# 99          pension:credited,telephone bill:accounted
#
#                                         company_names
# 0   STARK INDUSTRIES,INTERCONNECT TECH,ENERGY DIST...
# 1                                      PYM INDUSTRIES
# 2   STARK INDUSTRIES,CONNECTION GENE,ENERGY DISTRI...
# 3   BURNS INDUSTRIES,PYM INDUSTRIES,INTERCONNECT TECH
# 4                                    STARK INDUSTRIES
# 5   POWER CORP,PYM INDUSTRIES,INTERCONNECT TECH,ST...
# 6                     PYM INDUSTRIES,STARK INDUSTRIES
# 7    ENERGY DISTRIBUTORS,SUPER NETWORK,PYM INDUSTRIES
# 8   STARK INDUSTRIES,INTERCONNECT TECH,ENERGY DIST...
# 9   ACME CORP,SUPER NETWORK,BURNS INDUSTRIES,ENERG...
# 10                       PYM INDUSTRIES,SUPER NETWORK
# 11                                    CONNECTION GENE
# 12  POWER CORP,ENERGY DISTRIBUTORS,INTERCONNECT TE...
# 13              ENERGY DISTRIBUTORS,INTERCONNECT TECH
# 14                   CONNECTION GENE,BURNS INDUSTRIES
# 15                                   BURNS INDUSTRIES
# 16                                  INTERCONNECT TECH
# 17     POWER CORP,ENERGY DISTRIBUTORS,CONNECTION GENE
# 18  ENERGY DISTRIBUTORS,ACME CORP,POWER CORP,CONNE...
# 19  CONNECTION GENE,STARK INDUSTRIES,POWER CORP,PY...
# 20  ENERGY DISTRIBUTORS,BURNS INDUSTRIES,INTERCONN...
# 21                            SUPER NETWORK,ACME CORP
# 22                                          ACME CORP
# 23  STARK INDUSTRIES,BURNS INDUSTRIES,SUPER NETWOR...
# 24  BURNS INDUSTRIES,STARK INDUSTRIES,INTERCONNECT...
# 25                         ACME CORP,STARK INDUSTRIES
# 26              ENERGY DISTRIBUTORS,INTERCONNECT TECH
# 27                     POWER CORP,ENERGY DISTRIBUTORS
# 28                     CONNECTION GENE,PYM INDUSTRIES
# 29      SUPER NETWORK,PYM INDUSTRIES,BURNS INDUSTRIES
# ..                                                ...
# 70                     STARK INDUSTRIES,SUPER NETWORK
# 71  STARK INDUSTRIES,INTERCONNECT TECH,POWER CORP,...
# 72                 ACME CORP,SUPER NETWORK,POWER CORP
# 73             PYM INDUSTRIES,SUPER NETWORK,ACME CORP
# 74                 INTERCONNECT TECH,BURNS INDUSTRIES
# 75                                   STARK INDUSTRIES
# 76      INTERCONNECT TECH,POWER CORP,STARK INDUSTRIES
# 77            SUPER NETWORK,PYM INDUSTRIES,POWER CORP
# 78  CONNECTION GENE,POWER CORP,ACME CORP,PYM INDUS...
# 79             SUPER NETWORK,ACME CORP,PYM INDUSTRIES
# 80                  BURNS INDUSTRIES,STARK INDUSTRIES
# 81                                      SUPER NETWORK
# 82                   PYM INDUSTRIES,INTERCONNECT TECH
# 83                    PYM INDUSTRIES,BURNS INDUSTRIES
# 84                    PYM INDUSTRIES,BURNS INDUSTRIES
# 85                         ACME CORP,STARK INDUSTRIES
# 86               BURNS INDUSTRIES,ENERGY DISTRIBUTORS
# 87                          PYM INDUSTRIES,POWER CORP
# 88  ENERGY DISTRIBUTORS,INTERCONNECT TECH,PYM INDU...
# 89          PYM INDUSTRIES,ACME CORP,BURNS INDUSTRIES
# 90                           ACME CORP,PYM INDUSTRIES
# 91                                   STARK INDUSTRIES
# 92  STARK INDUSTRIES,INTERCONNECT TECH,BURNS INDUS...
# 93                                          ACME CORP
# 94                    PYM INDUSTRIES,STARK INDUSTRIES
# 95                                   BURNS INDUSTRIES
# 96             ACME CORP,INTERCONNECT TECH,POWER CORP
# 97           BURNS INDUSTRIES,SUPER NETWORK,ACME CORP
# 98  PYM INDUSTRIES,STARK INDUSTRIES,INTERCONNECT T...
# 99                   STARK INDUSTRIES,CONNECTION GENE
#
# [100 rows x 12 columns]
